# %% [markdown]
# # Scrape Book Reviews from Goodreads
#
# ## 1. Single Pages

# %%
import requests
from bs4 import BeautifulSoup  
import pandas as pd
import re

def getReviews(page_url):
 # add your code here
    
    # request the url
    page = requests.get(page_url)
    d=BeautifulSoup(page.text, 'html.parser')
    
    # get the value of 'name', 'date', 'review', 'like'
    name = d.find_all('a', class_='user')
    date = d.find_all('a', class_='reviewDate createdAt right')
    review = d.find_all("div", {"class": "reviewText stacked"})
    like = d.find_all('span', class_='likeItContainer')
    
    # get the value of 'rating', [progressing NA value]
    review_state = d.find_all('div', class_="reviewHeader uitext stacked")
    rating = []
    for i in range(len(review_state)):
        if 'rated it' in review_state[i].get_text():
            rate_i = review_state[i].find_all('span', class_='staticStars notranslate')[0].get_text()
            rating.append(rate_i)
        else:
            rating.append(None)
    
    # extract text from data
    name = list(map(lambda x: x.get_text(), name))
    date = list(map(lambda x: x.get_text(), date))
    review = list(map(lambda x: x.get_text(), review))
    like = list(map(lambda x: x.get_text(), like))
    
    # define a dataframe of different variables
    reviews = pd.DataFrame({'name':name, 'rating':rating, 'date':date, 'review':review, 'like':like})
    
    # clean data
    reviews.like = reviews['like'].str.extract('(\d+)')
    reviews['review'] = reviews['review'].apply(lambda x:x.replace('\n', ''))
    
    return reviews

# %%
# enter your own url
page_url = 'https://www.goodreads.com/book/show/36320.Tales_of_the_Cthulhu_Mythos'

reviews=getReviews(page_url)
reviews
# Out:
#                 name           rating          date  \
# 0            Stephen   it was amazing  Oct 10, 2008
# 1             Werner   it was amazing  Jul 15, 2009
# 2      Ashley Daviau        it was ok  Mar 30, 2020
# 3           S̶e̶a̶n̶             None  Nov 08, 2019
# 4      Marsha Altman         liked it  Oct 15, 2011
# 5             Harris         liked it  Oct 03, 2013
# 6           Myridian   it was amazing  Mar 18, 2008
# 7       John Frasene         liked it  Nov 12, 2017
# 8      Edward Taylor   it was amazing  Apr 28, 2018
# 9      Félix D'Jesús  really liked it  Nov 02, 2019
# 10            Nashid         liked it  Jan 12, 2020
# 11           Whiskey             None  Sep 02, 2019
# 12     Jeff Stockett  really liked it  Jan 05, 2010
# 13             Laura         liked it  Mar 10, 2013
# 14            Evelyn         liked it  Oct 16, 2013
# 15              Josh        it was ok  Jul 19, 2013
# 16           Patrick        it was ok  Nov 13, 2011
# 17    Hunter Duesing   it was amazing  Jul 09, 2008
# 18   Richard Houchin  really liked it  Apr 23, 2008
# 19            Connie  really liked it  Mar 18, 2011
# 20            Konrad   it was amazing  Oct 06, 2012
# 21     Nick Chianese  really liked it  Aug 20, 2020
# 22              Adam  really liked it  May 31, 2018
# 23           Liam J.  did not like it  Jan 12, 2022
# 24  Christine McCann  really liked it  May 29, 2017
# 25          Kathleen        it was ok  Mar 05, 2018
# 26      Akshit Kumar   it was amazing  Feb 08, 2020
# 27              John         liked it  Jun 09, 2020
# 28                KP         liked it  Jul 03, 2020
# 29             Glenn   it was amazing  Aug 26, 2021
#
#                                                review like
# 0   Iä! Iä! Cthulhu Fhtagn!…but not forever:If the...   68
# 1   Note, May 3, 2020: When I read short story col...   25
# 2   Before I get surprised comments at me giving a...   16
# 3   Stories read:'The Call of Cthulhu' / H. P. Lov...    9
# 4   I can't give it more than three stars because ...    4
# 5   There are some very interesting stories in thi...    2
# 6   This is a collection of stories by H. P. Lovec...    2
# 7   This book as a whole was a bit disappointing b...    2
# 8   Here we have just the right mix of modern auth...    1
# 9              Sticks by Karl Edward Wagner 🌟 🌟 🌟 🌟 🌟    1
# 10        Learning about the mythos from the classics    1
# 11  Cthulhu is a creature of enormous size and mal...  NaN
# 12  I really enjoyed this book. It was an excellen...    1
# 13  Took me weeks to finish this book. And I reall...    1
# 14  An mixed bag of short stories, two by H.P Love...    1
# 15  Meh... Some of the authors / stories were alri...    1
# 16  If nothing else, this book taught me that I am...    1
# 17  A perfect primer to Lovecraft's Cthulhu Mythos...    1
# 18  The greatest fear is fear of the unknown," sai...    1
# 19  The verbose gentleman with bean-reeking breath...    1
# 20  Reviews of stories follow:The Call of CthulhuB...  NaN
# 21  Perfect for those (like me) who've read everyt...  NaN
# 22                      This review has been hidde...  NaN
# 23  I honestly don't believe that this review will...  NaN
# 24  This is a great anthology for anyone intereste...  NaN
# 25  Or, White Men Are Dumbasses, The Anthology.I p...  NaN
# 26  Classic mythos fiction by Lovecraft alongside ...  NaN
# 27  It's hard to know how to judge a book when you...  NaN
# 28  Loses a star, as always, for the rampant racis...  NaN
# 29  There’s a remarkably high Hit/Miss ratio in th...  NaN

# %% [markdown]
# ## 2. All Pages with selenium

# %%
from selenium import webdriver
import time

# define a new function to get single page data
def singe_page(d):
    # get the value of 'name', 'date', 'review', 'like'
    name = d.find_all('a', class_='user')
    date = d.find_all('a', class_='reviewDate createdAt right')
    review = d.find_all("div", {"class": "reviewText stacked"})
    like = d.find_all('span', class_='likeItContainer')
    
    # get the value of 'rating', [progressing NA value]
    review_state = d.find_all('div', class_="reviewHeader uitext stacked")
    rating = []
    for i in range(len(review_state)):
        if 'rated it' in review_state[i].get_text():
            rate_i = review_state[i].find_all('span', class_='staticStars notranslate')[0].get_text()
            rating.append(rate_i)
        else:
            rating.append(None)
    
    # extract text from data
    name = list(map(lambda x: x.get_text(), name))
    date = list(map(lambda x: x.get_text(), date))
    review = list(map(lambda x: x.get_text(), review))
    like = list(map(lambda x: x.get_text(), like))
    
    # define a dataframe of different variables
    reviews = pd.DataFrame({'name':name, 'rating':rating, 'date':date, 'review':review, 'like':like})
    
    # clean data
    reviews.like = reviews['like'].str.extract('(\d+)')
    reviews['review'] = reviews['review'].apply(lambda x:x.replace('\n', ''))
    
    return reviews

# %%
def getReviews_2(page_url):

 # add your code here
    # get 1 st page data
    page = requests.get(page_url)
    d=BeautifulSoup(page.text, 'html.parser')
    reviews_1 = singe_page(d)
    reviews = [reviews_1]
    # get others page data
    for i in range(4):
        page = str(i+2)
        driver = webdriver.Safari(executable_path='/usr/bin/safaridriver') # use safari browser as core
        driver.get(page_url)
        time.sleep(2)
        driver.find_element_by_link_text(page).click()                     # turn to specific pages
        time.sleep(3)
        source = driver.page_source                                        # get the source of that page
        d=BeautifulSoup(source, 'html.parser')
        time.sleep(2)  
        reviews_i = singe_page(d)                                          # get data of that page
        driver.close()
        reviews.append(reviews_i)
        time.sleep(2) 
    # concat all pages    
    reviews = pd.concat(reviews)

    return reviews

# %%
# enter your own url
#page_url = 'https://www.goodreads.com/book/show/52578297-the-midnight-library?from_choice=true'
page_url = 'https://www.goodreads.com/book/show/36320.Tales_of_the_Cthulhu_Mythos'
reviews=getReviews_2(page_url)
reviews
# Out:
# /var/folders/5j/nt755xf54zzfpdq3437fz8l00000gn/T/ipykernel_25125/730517592.py:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text(page).click()
#                 name          rating          date  \
# 0            Stephen  it was amazing  Oct 10, 2008
# 1             Werner  it was amazing  Jul 15, 2009
# 2      Ashley Daviau       it was ok  Mar 30, 2020
# 3           S̶e̶a̶n̶            None  Nov 08, 2019
# 4      Marsha Altman        liked it  Oct 15, 2011
# ..               ...             ...           ...
# 2              Kelly        liked it  Jan 02, 2008
# 3       Andrew Black  it was amazing  Jan 17, 2011
# 4               Dale        liked it  Jun 13, 2011
# 5   James Kinniburgh            None  Feb 13, 2013
# 6     Nicholas Lewis            None  Mar 04, 2014
#
#                                                review like
# 0   Iä! Iä! Cthulhu Fhtagn!…but not forever:If the...   68
# 1   Note, May 3, 2020: When I read short story col...   25
# 2   Before I get surprised comments at me giving a...   16
# 3   Stories read:'The Call of Cthulhu' / H. P. Lov...    9
# 4   I can't give it more than three stars because ...    4
# ..                                                ...  ...
# 2                another book i would like to reread.  NaN
# 3   Possibly one of the best introductory antholog...  NaN
# 4   A decent cross section of Cthulhu mythos stori...  NaN
# 5                       Could not download this book.  NaN
# 6   Fantastic tales that will grip you right from ...  NaN
#
# [127 rows x 5 columns]

# %% [markdown]
# https://www.goodreads.com/book/show/806933.Tales_of_the_Cthulhu_Mythos#
